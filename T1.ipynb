# %%
#
# SOMENTE EXECUTE SE NO colab.research.google.com
#
# !pip install pymongo[srv,tls]
# !pip install dnspython
from tensorflow.python.client import device_lib

print("Show System RAM Memory:\n\n")
# !cat /proc/meminfo | egrep "MemTotal*"


print("\n\nShow Devices:\n\n"+str(device_lib.list_local_devices()))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 13.5 MB/s eta 0:00:00
# ...
# Show System RAM Memory:
#
#
# MemTotal:       13294208 kB
#
#
# Show Devices:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 501676067262965268
# xla_global_id: -1
# ]

# %%
import pymongo
import dns
import pandas as pd
from urllib import request
from pprint import pprint
import datetime as dt
import json
import socket
from IPython.display import display
host_name = socket.gethostname()
host_ip = socket.gethostbyname(host_name)
print("Hostname :  ",host_name)
print("IP : ",host_ip)
# Out:
# Hostname :   ab30539a03cc
# IP :  172.28.0.12

# %%
connection_string = 'mongodb+srv://lucatemes:admin@dados01.vfokyx2.mongodb.net/?retryWrites=true&w=majority'
client = pymongo.MongoClient(connection_string)

BDII_T1 = client.dados01

# %%
BD2_turma = {'Codicred':"99999-02",
             'Denominacao':"BD2",
             'Turma':10,
             'Ano_Semestre':"2023/2",
             'Horarios':"2CD",
             'Sala':"32/A",
             'Professor':"Duncan",
             'Alunos':[]
            }

pprint(BD2_turma)
# Out:
# {'Alunos': [],
#  'Ano_Semestre': '2024/2',
#  'Codicred': '99999-02',
#  'Denominacao': 'BD2',
#  'Horarios': '2CD',
#  'Professor': 'Aaaaa',
#  'Sala': '32/?',
#  'Turma': 10}

# %%
result = BDII_T1.TURMAS.insert_one(BD2_turma)

# %%
BD2_aluno = {'Matricula':22103097,
             'Nome':'Luca Temes D`Andrea',
             'Endereco':"Porto Alegre Zona Norte",
             'Curso':{'Codigo':"98AH ",
                      'Titulo':"Ciência da Computação"
                      },
             'Email': "luca.temes@edu.pucrs.br",
             'Data_Ingresso':"2022-02-01T00:00:00",
             'Discs_Matriculadas':
                  [{'Codicred':"98902-02",
                    'Turma':10,
                    'Ano_Semestre':"2023/2",
                    'Situacao':"Ativo",
                    'Frequencia':70},
                   {'Codicred':"9871604",
                    'Turma':30,
                    'Ano_Semestre':"2023/2",
                    'Situacao':"Ativo",
                    'Frequencia':75},
                  ],
             'Discs_Historico':
                  [{'Codicred':"4651504",
                    'Turma':691,
                    'Ano_Semestre':"2023/1",
                    'Situacao':"Aprovado",
                    'Nota':7.0},
                    {'Codicred':"9870104",
                    'Turma':11,
                    'Ano_Semestre':"2023/1",
                    'Situacao':"Aprovado",
                    'Nota':7.1},
                   {'Codicred':"4611F04",
                    'Turma':11,
                    'Ano_Semestre':"2023/1",
                    'Situacao':"Aprovado",
                    'Nota':7.3}
                   ]
              }

BD2_aluno
# Out:
# {'Matricula': 22103097,
#  'Nome': 'Luca Temes D`Andrea',
#  'Endereco': 'Porto Alegre Zona Norte',
#  'Curso': {'Codigo': '98AH ', 'Titulo': 'Ciência da Computação'},
#  'Email': 'luca.temes@edu.pucrs.br',
#  'Data_Ingresso': '2022-02-01T00:00:00',
#  'Discs_Matriculadas': [{'Codicred': '98902-02',
#    'Turma': 10,
#    'Ano_Semestre': '2023/2',
#    'Situacao': 'Ativo',
#    'Frequencia': 70},
#   {'Codicred': '9871604',
#    'Turma': 30,
#    'Ano_Semestre': '2023/2',
#    'Situacao': 'Ativo',
#    'Frequencia': 75}],
#  'Discs_Historico': [{'Codicred': '4651504',
#    'Turma': 691,
#    'Ano_Semestre': '2023/1',
#    'Situacao': 'Aprovado',
#    'Nota': 7.0},
#   {'Codicred': '9870104',
#    'Turma': 11,
#    'Ano_Semestre': '2023/1',
#    'Situacao': 'Aprovado',
#    'Nota': 7.1},
#   {'Codicred': '4611F04',
#    'Turma': 11,
#    'Ano_Semestre': '2023/1',
#    'Situacao': 'Aprovado',
#    'Nota': 7.3}]}

# %%
result = BDII_T1.ALUNOS.insert_one(BD2_aluno)

# %%
matricula = BD2_aluno['Matricula']
nome = BD2_aluno['Nome']
Matriculas = BD2_aluno['Discs_Matriculadas']
for matr in Matriculas:
  BDII_T1.TURMAS.update_one({'Codicred':matr['Codicred'], 'Turma':matr['Turma'], 'Ano_Semestre':matr['Ano_Semestre']},
      {'$push':{'Alunos':{'Matricula': matricula, 'Nome': nome}}})
  result = BDII_T1.TURMAS.find({'Codicred':matr['Codicred'], 'Turma':matr['Turma'], 'Ano_Semestre':matr['Ano_Semestre']})
  pprint(list(result))
# Out:
# [{'Alunos': [{'Matricula': 22103097, 'Nome': 'Luca Temes D`Andrea'}],
#   'Ano_Semestre': '2023/2',
#   'Codicred': '98902-02',
#   'Horarios': '2CD',
#   'Professor': 'Duncan',
#   'Sala': '32/A/216',
#   'Turma': 10,
#   '_id': ObjectId('6535e2a7a058bd4e9cd5d25a')}]
# []

# %%
BD2_curso= {
                "Nivel":7,
                "Codicred":"4646M-04",
                "Denominacao":"Metodos Formais para Computacao"
            }

result = BDII_T1.CURSOSDISCS.insert_one(BD2_curso)

# %%
#a) (1,0) Lista de disciplinas (Codicred, Turma, Horario, Professor) sendo cursadas neste semestre e
#respectivos alunos (Matricula, Nome);

filtro2 = {"Ano_Semestre": "2023/1"}
curso = BDII_T1.TURMAS.find(filtro2)

for cursos in curso:
    print(cursos.get("Alunos", []))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [{'Matricula': 21103839, 'Nome': 'Eduardo da Silva'}]
# None
# None
# None
# None
# None
# None
# None
# [{'Matricula': 21108293, 'Nome': 'Marcelo da Silva'}, {'Matricula': 21112046, 'Nome': 'Tiago da Silva'}]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
#b) (1,0) Codicred, Denominacao e média de notas dos alunos, nas disciplinas cursadas no semestre
#passado;
filtro2 = {"Ano_Semestre": "2023/1"}
curso = BDII_T1.TURMAS.find(filtro2)

for cursos in curso:
  print(cursos.get("Codicred", []))
  print(cursos.get("Denominacao", []))
# Out:
# 13397-02
# Psicologia e Gestao de Pessoas em TI
# 4117D-04
# Calculo III
# 4117D-04
# Calculo III
# 4452A-02
# Introducao a Engenharia de Computacao
# 4452A-02
# Introducao a Engenharia de Computacao
# 4456C-04
# Microeletronica
# 4456W-02
# Estagio Supervisionado - Ec (190 Hrs)
# 4471V-02
# Sistemas de Planejamento e Custos para Engenharia
# 4471V-02
# Sistemas de Planejamento e Custos para Engenharia
# 4471X-02
# Engenharia Economica
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# Fundamentos de Programacao
# 4611C-06
# ...

# %%
#c) (1,0) uma outra consulta à sua escolha; definir também o enunciado em português

# filtrar alunos matriculados em ciência da computação

filtro2 = {"Curso": "Object"}
aluno = BDII_T1.ALUNOS.find()

for alunos in aluno:
  if(alunos.get("Curso", []).get("Titulo", []) == "Ciencia da Computacao"):
    print(alunos.get("Nome", []))
    print(alunos.get("Curso", []))
# Out:
# Eduardo da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Marcelo da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Tiago da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Vanessa da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Carla da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Rogerio da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Solange da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Marcelo da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
# Katia da Silva
# {'Codigo': '98AJ ', 'Titulo': 'Ciencia da Computacao'}
